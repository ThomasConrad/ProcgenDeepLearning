# %% [markdown]
# # Deep Learning Project - KK Testbench
#
# Currently testing difference between with/without mixreg

# %%
# Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
from utils import make_env, Storage, orthogonal_init

import csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4973b6a5c367> in <module>
#       3 import torch.nn as nn
#       4 import torch.nn.functional as F
# ----> 5 from utils import make_env, Storage, orthogonal_init
#       6
#       7 import csv
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# ### Hyperparameters
# Leave unchanged between comparison runs

# %%
# Hyperparameters
total_steps = 5e6
num_envs = 32
num_levels = 10
num_steps = 256
num_epochs = 3
batch_size = 256
eps = .2
grad_eps = .5
value_coef = .75
entropy_coef = .01

increase = 2 # How much to augment the dataset with mixreg
alpha = 0.5 # Alpha value to use for the beta-distribution in mixreg

# %% [markdown]
# ### Network Definition
# Leave unchanged between comparison runs

# %%
# Network definition
class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size(0), -1)

class RandomCrop(nn.Module, size=48):
    def forward(self, x):
        n, c, h, w = x.shape
        w1 = torch.randint(0, w - size + 1, (n,))
        h1 = torch.randint(0, h - size + 1, (n,))
        cropped = torch.empty((n, c, size, size), dtype=x.dtype, device=x.device)
        for i, (img, w11, h11) in enumerate(zip(x, w1, h1)):
            cropped[i][:] = img[:, h11:h11 + size, w11:w11 + size]
        return cropped

class ResidualBlock(nn.Module):
  def __init__(self, in_channels):
    super().__init__()
    self.layers = nn.Sequential(
        nn.ReLU(),
        nn.Conv2d(in_channels=in_channels, out_channels=in_channels, kernel_size=3, stride=1, padding=1),
        nn.ReLU(),
        nn.Conv2d(in_channels=in_channels, out_channels=in_channels, kernel_size=3, stride=1, padding=1)
    )

  def forward(self, x):
    return self.layers(x) + x

class ImpalaBlock(nn.Module):
  def __init__(self, in_channels, out_channels):
    super().__init__()
    self.layers = nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=1, padding=1),
        nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
        ResidualBlock(out_channels),
        ResidualBlock(out_channels)
    )

  def forward(self, x):
    return self.layers(x)

class SimpleImpalaEncoder(nn.Module):
  def __init__(self, in_channels, feature_dim):
    super().__init__()
    self.layers = nn.Sequential(
        ImpalaBlock(in_channels, out_channels=16),
        ImpalaBlock(in_channels=16, out_channels=32),
        ImpalaBlock(in_channels=32, out_channels=32),
        nn.ReLU(),
        Flatten(),
        nn.Linear(in_features=2048, out_features=feature_dim),
        nn.ReLU()
    )
  
  def forward(self, x):
    return self.layers(x)

class Encoder(nn.Module):
  def __init__(self, in_channels, feature_dim):
    super().__init__()
    self.layers = nn.Sequential(
        nn.Conv2d(in_channels=in_channels, out_channels=32, kernel_size=8, stride=4), nn.ReLU(),
        nn.BatchNorm2d(num_features=32),
        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2), nn.ReLU(),
        nn.BatchNorm2d(num_features=64),
        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1), nn.ReLU(),
        nn.BatchNorm2d(num_features=128),
        nn.Conv2d(in_channels=128, out_channels=64, kernel_size=3, stride=1), nn.ReLU(),
        Flatten(),
        nn.Linear(in_features=1024, out_features=feature_dim), nn.ReLU()
    )
    self.apply(orthogonal_init)

  def forward(self, x):
    return self.layers(x)


class Policy(nn.Module):
  def __init__(self, encoder, feature_dim, num_actions):
    super().__init__()
    self.encoder = encoder
    self.policy = orthogonal_init(nn.Linear(feature_dim, num_actions), gain=.01)
    self.value = orthogonal_init(nn.Linear(feature_dim, 1), gain=1.)

  def act(self, x):
    with torch.no_grad():
      x = x.cuda().contiguous()
      dist, value = self.forward(x)
      action = dist.sample()
      log_prob = dist.log_prob(action)
    
    return action.cpu(), log_prob.cpu(), value.cpu()

  def forward(self, x):
    x = self.encoder(x)
    logits = self.policy(x)
    value = self.value(x).squeeze(1)
    dist = torch.distributions.Categorical(logits=logits)

    return dist, value

# %% [markdown]
# ## Environment and training definition

# %%
# Change this for comparison purposes
use_mixreg  = True

# Define environment
# check the utils.py file for info on arguments
env = make_env(num_envs, num_levels=num_levels)
print('Observation space:', env.observation_space)
print('Action space:', env.action_space.n)

# Define validation environment
eval_env = make_env(num_envs, start_level=num_levels, num_levels=num_levels,env_name='starpilot')

# Define network
encoder = SimpleImpalaEncoder(3,256)
policy = Policy(encoder, 256, env.action_space.n)
policy.cuda()

# Define optimizer
# these are reasonable values but probably not optimal
optimizer = torch.optim.Adam(policy.parameters(), lr=5e-4, eps=1e-5,weight_decay = 1e-5)

# Define temporary storage
# we use this to collect transitions during each iteration
storage = Storage(
    env.observation_space.shape,
    num_steps,
    num_envs
)

## Filename for checkpoints
checkpoint_file_name = 'checkpoint'
if use_mixreg:
    checkpoint_file_name += '_mixreg'
else:
    checkpoint_file_name += '_basic'
checkpoint_file_name += '.pt'

data_log_file_name = 'training_stats'
if use_mixreg:
    data_log_file_name += '_mixreg'
else:
    data_log_file_name += '_basic'
data_log_file_name += '.csv'
# Out:
# Observation space: Box(0.0, 1.0, (3, 64, 64), float32)
# Action space: 15

# %% [markdown]
# ## Training Loop

# %%
# Run training
obs = env.reset()
v_obs = eval_env.reset()
step = 0

data_log = []
while step < total_steps:

  # Use policy to collect data for num_steps steps
  policy.eval()
  for _ in range(num_steps):
    # Use policy
    action, log_prob, value = policy.act(obs)
    
    # Take step in environment
    next_obs, reward, done, info = env.step(action)

    # Store data
    storage.store(obs, action, reward, done, info, log_prob, value)
    
    # Update current observation
    obs = next_obs

  # Add the last observation to collected data
  _, _, value = policy.act(obs)
  storage.store_last(obs, value)

  # Compute return and advantage
  storage.compute_return_advantage()

  # Optimize policy
  policy.train()
  for epoch in range(num_epochs):

    # Iterate over batches of transitions
    if use_mixreg:
        generator = storage.get_mix_generator(increase, alpha, batch_size)
    else:
        generator = storage.get_generator(batch_size)
        
    for batch in generator:
      b_obs, b_action, b_log_prob, b_value, b_returns, b_advantage = batch

      # Get current policy outputs
      new_dist, new_value = policy(b_obs)
      new_log_prob = new_dist.log_prob(b_action)

      # Clipped policy objective
      ratio = torch.exp(new_log_prob - b_log_prob)
      clipped_ratio = ratio.clamp(min=1.0 - eps,max=1.0 + eps)
      policy_reward = torch.min(ratio * b_advantage, clipped_ratio * b_advantage)
      pi_loss = -policy_reward.mean()

      # Clipped value function objective
      V_clip = b_value + (new_value-b_value).clamp(-eps,eps)
      vf_loss = torch.max((b_value - b_returns) ** 2, (V_clip - b_returns) ** 2)
      value_loss = 0.5*vf_loss.mean()

      # Entropy loss
      entropy_loss = new_dist.entropy().mean()

      # Backpropagate losses
      loss = pi_loss + value_coef * value_loss - entropy_coef * entropy_loss
      loss.backward()

      # Clip gradients
      torch.nn.utils.clip_grad_norm_(policy.parameters(), grad_eps)

      # Update policy
      optimizer.step()
      optimizer.zero_grad()

  ## VALIDATION ##
  # Evaluate policy
  policy.eval()
  validation_reward = []
  for _ in range(num_steps):
    # Use policy
    v_action, v_log_prob, v_value = policy.act(v_obs)

    # Take step in environment
    v_obs, v_reward, v_done, v_info = eval_env.step(v_action)
    validation_reward.append(torch.Tensor(v_reward))

  # Calculate average return
  validation_reward = torch.stack(validation_reward).sum(0).mean(0)
  ## END OF VALIDATION ##

  # Update stats
  step += num_envs * num_steps
  print(f'Step: {step}\tMean reward: {storage.get_reward()}\tMean validation reward: {validation_reward}')
  data_point = [step, storage.get_reward().item(), validation_reward.item()]
  data_log.append(data_point)
    
with open(data_log_file_name, 'w', newline='') as f:
  writer = csv.writer(f)
  writer.writerows(data_log)

print('Completed training!')
torch.save(policy.state_dict, checkpoint_file_name)
# Out:
# Step: 8192	Mean reward: 3.75	Mean validation reward: 9.336302757263184
# Step: 16384	Mean reward: 3.90625	Mean validation reward: 5.378912925720215
# Step: 24576	Mean reward: 3.84375	Mean validation reward: 5.4661970138549805
# Step: 32768	Mean reward: 4.25	Mean validation reward: 5.992478370666504
# Step: 40960	Mean reward: 3.65625	Mean validation reward: 5.05367374420166
# Step: 49152	Mean reward: 4.53125	Mean validation reward: 4.72085428237915
# Step: 57344	Mean reward: 3.34375	Mean validation reward: 4.361542701721191
# Step: 65536	Mean reward: 3.375	Mean validation reward: 4.637571334838867
# Step: 73728	Mean reward: 3.625	Mean validation reward: 5.608954906463623
# Step: 81920	Mean reward: 3.96875	Mean validation reward: 5.128689765930176
# Step: 90112	Mean reward: 4.03125	Mean validation reward: 5.3725056648254395
# Step: 98304	Mean reward: 4.53125	Mean validation reward: 5.417236328125
# Step: 106496	Mean reward: 4.84375	Mean validation reward: 5.71299934387207
# Step: 114688	Mean reward: 4.65625	Mean validation reward: 6.203741073608398
# Step: 122880	Mean reward: 6.78125	Mean validation reward: 5.0148773193359375
# Step: 131072	Mean reward: 5.0625	Mean validation reward: 5.736665725708008
# Step: 139264	Mean reward: 4.78125	Mean validation reward: 6.6999921798706055
# Step: 147456	Mean reward: 6.84375	Mean validation reward: 5.382405757904053
# Step: 155648	Mean reward: 6.34375	Mean validation reward: 5.7905378341674805
# Step: 163840	Mean reward: 7.09375	Mean validation reward: 5.493696212768555
# Step: 172032	Mean reward: 4.78125	Mean validation reward: 6.185518741607666
# Step: 180224	Mean reward: 4.96875	Mean validation reward: 6.155167579650879
# Step: 188416	Mean reward: 6.6875	Mean validation reward: 5.493614673614502
# Step: 1212416	Mean reward: 7.625	Mean validation reward: 4.747398853302002
# Step: 1220608	Mean reward: 7.625	Mean validation reward: 4.910297870635986
# Step: 1228800	Mean reward: 8.1875	Mean validation reward: 4.3839497566223145
# Step: 1236992	Mean reward: 8.65625	Mean validation reward: 5.495279312133789
# Step: 1245184	Mean reward: 8.15625	Mean validation reward: 5.498161792755127
# Step: 1253376	Mean reward: 8.71875	Mean validation reward: 5.057927131652832
# Step: 1261568	Mean reward: 8.5	Mean validation reward: 4.825439929962158
# Step: 1269760	Mean reward: 8.4375	Mean validation reward: 5.083040714263916
# Step: 1277952	Mean reward: 8.9375	Mean validation reward: 4.992394924163818
# Step: 1286144	Mean reward: 8.125	Mean validation reward: 4.856666088104248
# Step: 1294336	Mean reward: 8.03125	Mean validation reward: 4.997094631195068
# Step: 1302528	Mean reward: 7.5625	Mean validation reward: 5.483260154724121
# Step: 1310720	Mean reward: 8.53125	Mean validation reward: 4.948883533477783
# Step: 1318912	Mean reward: 8.0625	Mean validation reward: 5.225531101226807
# Step: 1327104	Mean reward: 7.96875	Mean validation reward: 4.372222900390625
# Step: 1335296	Mean reward: 8.1875	Mean validation reward: 4.885542392730713
# Step: 1343488	Mean reward: 7.65625	Mean validation reward: 4.843752861022949
# Step: 1351680	Mean reward: 7.9375	Mean validation reward: 4.448100566864014
# Step: 1359872	Mean reward: 8.96875	Mean validation reward: 5.052836894989014
# Step: 1368064	Mean reward: 7.21875	Mean validation reward: 4.012997627258301
# Step: 1376256	Mean reward: 7.53125	Mean validation reward: 4.204547882080078
# Step: 1384448	Mean reward: 7.75	Mean validation reward: 4.41793155670166
# Step: 1392640	Mean reward: 8.65625	Mean validation reward: 4.839968681335449
# Step: 1400832	Mean reward: 6.8125	Mean validation reward: 5.191858291625977
# Step: 1409024	Mean reward: 8.21875	Mean validation reward: 4.960120677947998
# Step: 1417216	Mean reward: 7.4375	Mean validation reward: 4.68405294418335
# Step: 1425408	Mean reward: 7.15625	Mean validation reward: 4.873918056488037
# Step: 1433600	Mean reward: 8.40625	Mean validation reward: 4.68809700012207
# Step: 1441792	Mean reward: 8.0	Mean validation reward: 5.504410266876221
# Step: 1449984	Mean reward: 8.28125	Mean validation reward: 5.340451240539551
# Step: 1458176	Mean reward: 6.6875	Mean validation reward: 6.014919281005859
# Step: 1466368	Mean reward: 8.0	Mean validation reward: 5.519640922546387
# Step: 1474560	Mean reward: 7.8125	Mean validation reward: 5.237643241882324
# Step: 1482752	Mean reward: 7.78125	Mean validation reward: 5.706275939941406
# Step: 1490944	Mean reward: 8.65625	Mean validation reward: 5.217513084411621
# Step: 1499136	Mean reward: 8.6875	Mean validation reward: 4.9848456382751465
# Step: 1507328	Mean reward: 9.78125	Mean validation reward: 5.520495891571045
# Step: 1515520	Mean reward: 8.84375	Mean validation reward: 5.147839546203613
# Step: 1523712	Mean reward: 9.4375	Mean validation reward: 4.893651008605957
# Step: 1531904	Mean reward: 9.03125	Mean validation reward: 5.129602432250977
# Step: 1540096	Mean reward: 8.65625	Mean validation reward: 5.6398444175720215
# Step: 1548288	Mean reward: 8.8125	Mean validation reward: 5.032268047332764
# Step: 1556480	Mean reward: 8.875	Mean validation reward: 5.429190635681152
# Step: 1564672	Mean reward: 6.78125	Mean validation reward: 5.29078483581543
# Step: 1572864	Mean reward: 8.40625	Mean validation reward: 5.618170261383057
# Step: 1581056	Mean reward: 8.4375	Mean validation reward: 5.640074729919434
# Step: 1589248	Mean reward: 8.78125	Mean validation reward: 5.9852776527404785
# Step: 1597440	Mean reward: 8.8125	Mean validation reward: 5.657279968261719
# Step: 1605632	Mean reward: 5.78125	Mean validation reward: 5.053786277770996
# Step: 1613824	Mean reward: 8.21875	Mean validation reward: 5.146038055419922
# Step: 1622016	Mean reward: 9.28125	Mean validation reward: 5.307929992675781
# Step: 1630208	Mean reward: 7.53125	Mean validation reward: 5.541419982910156
# Step: 1638400	Mean reward: 8.875	Mean validation reward: 5.981355667114258
# Step: 1646592	Mean reward: 7.21875	Mean validation reward: 4.955963134765625
# Step: 1654784	Mean reward: 8.1875	Mean validation reward: 5.190768241882324
# Step: 1662976	Mean reward: 7.4375	Mean validation reward: 5.493113040924072
# Step: 1671168	Mean reward: 8.5	Mean validation reward: 5.400060176849365
# Step: 1679360	Mean reward: 8.125	Mean validation reward: 4.935347557067871
# Step: 1687552	Mean reward: 7.8125	Mean validation reward: 4.888197898864746
# Step: 1695744	Mean reward: 6.8125	Mean validation reward: 5.005699157714844
# Step: 1703936	Mean reward: 8.625	Mean validation reward: 5.0530500411987305
# Step: 1712128	Mean reward: 7.40625	Mean validation reward: 4.774200439453125
# Step: 1720320	Mean reward: 7.90625	Mean validation reward: 5.7074713706970215
# Step: 1728512	Mean reward: 8.21875	Mean validation reward: 5.591707706451416
# Step: 1736704	Mean reward: 8.375	Mean validation reward: 5.654827117919922
# Step: 1744896	Mean reward: 7.46875	Mean validation reward: 5.213228225708008
# Step: 1753088	Mean reward: 6.75	Mean validation reward: 6.026792526245117
# Step: 1761280	Mean reward: 7.75	Mean validation reward: 5.071322441101074
# Step: 1769472	Mean reward: 7.125	Mean validation reward: 5.3500471115112305
# Step: 1777664	Mean reward: 8.59375	Mean validation reward: 5.81591796875
# Step: 1785856	Mean reward: 9.15625	Mean validation reward: 5.4667181968688965
# Step: 1794048	Mean reward: 8.15625	Mean validation reward: 4.791506290435791
# Step: 1802240	Mean reward: 7.28125	Mean validation reward: 5.56008243560791
# Step: 1810432	Mean reward: 7.59375	Mean validation reward: 5.23397970199585
# Step: 1818624	Mean reward: 8.25	Mean validation reward: 5.256682395935059
# Step: 1826816	Mean reward: 9.03125	Mean validation reward: 5.37369966506958
# Step: 1835008	Mean reward: 7.75	Mean validation reward: 5.977680206298828
# Step: 1843200	Mean reward: 8.40625	Mean validation reward: 5.325509071350098
# Step: 1851392	Mean reward: 8.59375	Mean validation reward: 5.071296691894531
# Step: 1859584	Mean reward: 8.8125	Mean validation reward: 4.282802104949951
# Step: 1867776	Mean reward: 8.09375	Mean validation reward: 5.566464424133301
# Step: 1875968	Mean reward: 8.875	Mean validation reward: 5.45005464553833
# Step: 1884160	Mean reward: 8.9375	Mean validation reward: 4.566097736358643
# Step: 1892352	Mean reward: 8.53125	Mean validation reward: 4.7321858406066895
# Step: 1900544	Mean reward: 7.96875	Mean validation reward: 4.875141143798828
# Step: 1908736	Mean reward: 7.65625	Mean validation reward: 5.7850446701049805
# Step: 1916928	Mean reward: 9.25	Mean validation reward: 4.757946968078613
# Step: 1925120	Mean reward: 9.40625	Mean validation reward: 4.876767635345459
# Step: 1933312	Mean reward: 8.53125	Mean validation reward: 6.228822708129883
# Step: 1941504	Mean reward: 8.8125	Mean validation reward: 4.987499713897705
# Step: 1949696	Mean reward: 8.65625	Mean validation reward: 5.126822471618652
# Step: 1957888	Mean reward: 9.0	Mean validation reward: 4.429346561431885
# Step: 1966080	Mean reward: 8.96875	Mean validation reward: 4.851655006408691
# Step: 1974272	Mean reward: 9.03125	Mean validation reward: 4.761771202087402
# Step: 1982464	Mean reward: 8.0625	Mean validation reward: 5.067331314086914
# Step: 1990656	Mean reward: 7.875	Mean validation reward: 5.232483863830566
# Step: 1998848	Mean reward: 8.21875	Mean validation reward: 4.719545841217041
# Step: 2007040	Mean reward: 8.40625	Mean validation reward: 4.908984184265137
# Step: 2015232	Mean reward: 7.40625	Mean validation reward: 4.886350154876709
# Step: 2023424	Mean reward: 7.96875	Mean validation reward: 5.520678520202637
# Step: 2031616	Mean reward: 7.59375	Mean validation reward: 5.4269561767578125
# Step: 2039808	Mean reward: 8.59375	Mean validation reward: 5.21677303314209
# Step: 2048000	Mean reward: 8.9375	Mean validation reward: 5.076843738555908
# Step: 2056192	Mean reward: 8.3125	Mean validation reward: 5.054879188537598
# Step: 2064384	Mean reward: 8.875	Mean validation reward: 4.681697845458984
# Step: 2072576	Mean reward: 7.46875	Mean validation reward: 5.10471248626709
# Step: 2080768	Mean reward: 9.0625	Mean validation reward: 5.2469258308410645
# Step: 2088960	Mean reward: 7.5625	Mean validation reward: 5.271000862121582
# Step: 2097152	Mean reward: 8.03125	Mean validation reward: 5.5299224853515625
# Step: 2105344	Mean reward: 8.28125	Mean validation reward: 5.552801132202148
# Step: 2113536	Mean reward: 8.78125	Mean validation reward: 5.034093856811523
# Step: 2121728	Mean reward: 8.15625	Mean validation reward: 4.824436187744141
# Step: 2129920	Mean reward: 8.84375	Mean validation reward: 5.0596923828125
# Step: 2138112	Mean reward: 7.15625	Mean validation reward: 5.130119800567627
# Step: 2146304	Mean reward: 8.6875	Mean validation reward: 5.201592445373535
# Step: 2154496	Mean reward: 9.9375	Mean validation reward: 5.17888069152832
# Step: 2162688	Mean reward: 7.8125	Mean validation reward: 4.4776811599731445
# Step: 2170880	Mean reward: 8.1875	Mean validation reward: 5.5809221267700195
# Step: 2179072	Mean reward: 8.6875	Mean validation reward: 5.978202819824219
# Step: 2187264	Mean reward: 8.8125	Mean validation reward: 5.367432594299316
# Step: 2195456	Mean reward: 8.3125	Mean validation reward: 4.922397613525391
# Step: 2203648	Mean reward: 9.0	Mean validation reward: 4.127455711364746
# Step: 2211840	Mean reward: 9.59375	Mean validation reward: 5.233429908752441
# Step: 2220032	Mean reward: 8.3125	Mean validation reward: 5.679357051849365
# Step: 2228224	Mean reward: 7.15625	Mean validation reward: 5.1608476638793945
# Step: 2236416	Mean reward: 7.8125	Mean validation reward: 5.183309078216553
# Step: 2244608	Mean reward: 8.90625	Mean validation reward: 5.301567554473877
# Step: 2252800	Mean reward: 8.6875	Mean validation reward: 5.2307538986206055
# Step: 2260992	Mean reward: 7.625	Mean validation reward: 5.042383193969727
# Step: 2269184	Mean reward: 8.9375	Mean validation reward: 5.41816520690918
# Step: 2277376	Mean reward: 8.5	Mean validation reward: 4.8560004234313965
# Step: 2285568	Mean reward: 7.46875	Mean validation reward: 4.880460262298584
# Step: 2293760	Mean reward: 7.9375	Mean validation reward: 4.905704021453857
# Step: 2301952	Mean reward: 8.15625	Mean validation reward: 4.4832258224487305
# Step: 2310144	Mean reward: 7.40625	Mean validation reward: 4.955413341522217
# Step: 2318336	Mean reward: 7.6875	Mean validation reward: 4.815878868103027
# Step: 2326528	Mean reward: 8.5	Mean validation reward: 4.841039180755615
# Step: 2334720	Mean reward: 8.375	Mean validation reward: 5.031003475189209
# Step: 2342912	Mean reward: 7.375	Mean validation reward: 4.726600646972656
# Step: 2351104	Mean reward: 9.71875	Mean validation reward: 5.3646650314331055
# Step: 2359296	Mean reward: 7.78125	Mean validation reward: 4.823510646820068
# Step: 2367488	Mean reward: 9.09375	Mean validation reward: 4.8706231117248535
# Step: 2375680	Mean reward: 9.5625	Mean validation reward: 4.847034454345703
# Step: 2383872	Mean reward: 7.4375	Mean validation reward: 4.754497528076172
# Step: 2392064	Mean reward: 9.03125	Mean validation reward: 4.873612880706787
# Step: 2400256	Mean reward: 8.4375	Mean validation reward: 5.108126163482666
# Step: 2408448	Mean reward: 9.40625	Mean validation reward: 5.271231651306152
# Step: 2416640	Mean reward: 8.0	Mean validation reward: 5.341034412384033
# Step: 2424832	Mean reward: 9.875	Mean validation reward: 5.3416900634765625
# Step: 2433024	Mean reward: 7.90625	Mean validation reward: 5.107198715209961
# Step: 2441216	Mean reward: 7.34375	Mean validation reward: 5.413969993591309
# Step: 2449408	Mean reward: 8.1875	Mean validation reward: 5.648200511932373
# Step: 2457600	Mean reward: 7.65625	Mean validation reward: 4.7309746742248535
# Step: 2465792	Mean reward: 8.1875	Mean validation reward: 4.944695472717285
# Step: 2473984	Mean reward: 8.9375	Mean validation reward: 5.462575435638428
# Step: 2482176	Mean reward: 7.0	Mean validation reward: 5.180313587188721
# Step: 2490368	Mean reward: 9.375	Mean validation reward: 4.969310283660889
# Step: 2498560	Mean reward: 8.375	Mean validation reward: 5.55991792678833
# Step: 2506752	Mean reward: 8.875	Mean validation reward: 4.947124481201172
# Step: 2514944	Mean reward: 8.125	Mean validation reward: 4.429570198059082
# Step: 2523136	Mean reward: 8.09375	Mean validation reward: 5.230910301208496
# Step: 2531328	Mean reward: 7.4375	Mean validation reward: 5.064383029937744
# Step: 3530752	Mean reward: 7.59375	Mean validation reward: 5.353757381439209
# Step: 3538944	Mean reward: 8.40625	Mean validation reward: 5.257423400878906
# Step: 3547136	Mean reward: 8.1875	Mean validation reward: 5.065367221832275
# Step: 3555328	Mean reward: 7.90625	Mean validation reward: 5.401157855987549
# Step: 3563520	Mean reward: 8.625	Mean validation reward: 4.8254499435424805
# Step: 3571712	Mean reward: 7.75	Mean validation reward: 4.825516223907471
# Step: 3579904	Mean reward: 8.09375	Mean validation reward: 5.090496063232422
# Step: 3588096	Mean reward: 6.96875	Mean validation reward: 5.162423610687256
# Step: 3596288	Mean reward: 7.5	Mean validation reward: 5.257843494415283
# Step: 3604480	Mean reward: 8.5	Mean validation reward: 4.634093761444092
# Step: 3612672	Mean reward: 7.96875	Mean validation reward: 4.779545307159424
# Step: 3620864	Mean reward: 7.96875	Mean validation reward: 4.829051494598389
# Step: 3629056	Mean reward: 7.3125	Mean validation reward: 5.118434906005859
# Step: 3637248	Mean reward: 9.0	Mean validation reward: 4.927865982055664
# Step: 3645440	Mean reward: 7.65625	Mean validation reward: 4.759955883026123
# Step: 3653632	Mean reward: 8.9375	Mean validation reward: 4.568439483642578
# Step: 3661824	Mean reward: 7.375	Mean validation reward: 5.12349271774292
# Step: 3670016	Mean reward: 8.40625	Mean validation reward: 4.474809646606445
# Step: 3678208	Mean reward: 10.28125	Mean validation reward: 5.29292631149292
# Step: 3686400	Mean reward: 7.625	Mean validation reward: 4.307209014892578
# Step: 3694592	Mean reward: 7.625	Mean validation reward: 4.862623691558838
# Step: 3702784	Mean reward: 8.5	Mean validation reward: 5.344590187072754
# Step: 3710976	Mean reward: 9.0625	Mean validation reward: 4.863140106201172
# Step: 3719168	Mean reward: 8.03125	Mean validation reward: 5.105216979980469
# Step: 3727360	Mean reward: 8.9375	Mean validation reward: 4.8406524658203125
# Step: 3735552	Mean reward: 8.71875	Mean validation reward: 4.985685348510742
# Step: 3743744	Mean reward: 7.5625	Mean validation reward: 5.274834632873535
# Step: 3751936	Mean reward: 7.9375	Mean validation reward: 5.298437595367432
# Step: 3760128	Mean reward: 8.3125	Mean validation reward: 5.707063674926758
# Step: 3768320	Mean reward: 7.875	Mean validation reward: 5.56247091293335
# Step: 3776512	Mean reward: 9.0625	Mean validation reward: 5.3945231437683105
# Step: 3784704	Mean reward: 7.78125	Mean validation reward: 4.864042282104492
# Step: 3792896	Mean reward: 8.40625	Mean validation reward: 4.263462543487549
# Step: 3801088	Mean reward: 8.9375	Mean validation reward: 4.698879241943359
# Step: 3809280	Mean reward: 7.40625	Mean validation reward: 4.482635021209717
# Step: 3817472	Mean reward: 8.96875	Mean validation reward: 4.315412521362305
# Step: 3825664	Mean reward: 9.8125	Mean validation reward: 5.35182523727417
# Step: 3833856	Mean reward: 7.5625	Mean validation reward: 4.917089939117432
# Step: 3842048	Mean reward: 8.34375	Mean validation reward: 5.230929851531982
# Step: 3850240	Mean reward: 7.34375	Mean validation reward: 5.809544086456299
# Step: 3858432	Mean reward: 9.15625	Mean validation reward: 5.639293670654297
# Step: 4857856	Mean reward: 8.5625	Mean validation reward: 4.988108158111572
# Step: 4866048	Mean reward: 8.125	Mean validation reward: 5.303074836730957
# Step: 4874240	Mean reward: 7.78125	Mean validation reward: 5.254884719848633
# Step: 4882432	Mean reward: 8.0	Mean validation reward: 5.108515739440918
# Step: 4890624	Mean reward: 7.53125	Mean validation reward: 4.987569332122803
# Step: 4898816	Mean reward: 8.65625	Mean validation reward: 5.591092586517334
# Step: 4907008	Mean reward: 8.1875	Mean validation reward: 4.865021705627441
# Step: 4915200	Mean reward: 8.09375	Mean validation reward: 5.131535053253174
# Step: 4923392	Mean reward: 8.03125	Mean validation reward: 5.614439487457275
# Step: 4931584	Mean reward: 9.03125	Mean validation reward: 4.573329925537109
# Step: 4939776	Mean reward: 8.21875	Mean validation reward: 5.348796367645264
# Step: 4947968	Mean reward: 8.21875	Mean validation reward: 5.059195518493652
# Step: 4956160	Mean reward: 7.96875	Mean validation reward: 5.374258041381836
# Step: 4964352	Mean reward: 7.875	Mean validation reward: 4.188666820526123
# Step: 4972544	Mean reward: 8.59375	Mean validation reward: 5.666629314422607
# Step: 4980736	Mean reward: 7.53125	Mean validation reward: 4.69783878326416
# Step: 4988928	Mean reward: 8.53125	Mean validation reward: 5.399907112121582
# Step: 4997120	Mean reward: 8.65625	Mean validation reward: 5.278249740600586
# Step: 5005312	Mean reward: 7.71875	Mean validation reward: 4.987085342407227
# Completed training!

# %% [markdown]
# ### Vizualize training results
#
# Extraction:

# %%
import matplotlib.pyplot as plt
csv_files = [
  "training_stats_basic.csv"
  #"training_stats_mixreg.csv"
  ]

full_data = []

for file in csv_files:
  data = {}
  data['x'] = []
  data['y_train'] = []
  data['y_val'] = []

  with open(file, newline='') as f:
    reader = csv.reader(f)
    for row in reader:
      data['x'].append(int(row[0]))
      data['y_train'].append(float(row[1]))
      data['y_val'].append(float(row[2]))

  full_data.append(data)

# %% [markdown]
# Plotting:

# %%
plt.figure(figsize=(16,8))
colors = ["#2020FF","#FF8020"]
for i, data in enumerate(full_data):
  plt.plot(data['x'], data['y_train'], linestyle="-", color=colors[i],)
  plt.plot(data['x'], data['y_val'], linestyle="--", color=colors[i])

plt.legend(["Basic - Train","Basic - Validation"])
#plt.legend(["Basic - Train","Basic - Validation","w/ Mixreg - Train","w/ Mixreg - Validation"])



plt.show()

# %%
import imageio

# Make evaluation environment
eval_env = make_env(num_envs, start_level=num_levels, num_levels=num_levels,env_name='starpilot')
obs = eval_env.reset()

frames = []
total_reward = []

# Evaluate policy
policy.eval()
for _ in range(512):

  # Use policy
  action, log_prob, value = policy.act(obs)

  # Take step in environment
  obs, reward, done, info = eval_env.step(action)
  total_reward.append(torch.Tensor(reward))

  # Render environment and store
  frame = (torch.Tensor(eval_env.render(mode='rgb_array'))*255.).byte()
  frames.append(frame)

# Calculate average return
total_reward = torch.stack(total_reward).sum(0).mean(0)
print('Average return:', total_reward)

# Save frames as video
frames = torch.stack(frames)
imageio.mimsave('vid.mp4', frames, fps=25)
# Out:
# Average return: tensor(14.2768)
